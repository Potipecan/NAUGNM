# %% [markdown]
# # V 1.1

# %%
from common import *
# %load_ext autoreload
# %autoreload 2
# Out:
# 2025-11-18 19:11:49.108417: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
dim = 3000
x_train, y_train, x_test, y_test = load_dataset(dim)

model = init_model(dim, 16)

train(model, x_train, y_train)
# Out:
# 2025-11-18 19:11:57.429749: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "model_3000_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │        48,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 48,305 (188.69 KB)
#  Trainable params: 48,305 (188.69 KB)
#  Non-trainable params: 0 (0.00 B)
#     accuracy      loss  val_accuracy  val_loss
# 0    0.84055  0.369122        0.8832  0.289927
# 1    0.90205  0.249954        0.8796  0.292753
# 2    0.91715  0.212051        0.8754  0.324347
# 3    0.93200  0.175373        0.8712  0.337545
# 4    0.95020  0.133232        0.8678  0.380183
# 5    0.97010  0.089269        0.8592  0.465627
# 6    0.98200  0.056404        0.8622  0.510350
# 7    0.99070  0.034559        0.8564  0.593739
# 8    0.99520  0.020567        0.8596  0.717598
# 9    0.99765  0.011084        0.8596  0.809940
# 10   0.99550  0.014614        0.8496  0.894777
# 11   0.99350  0.020315        0.8536  0.899785
# 12   0.99505  0.016678        0.8496  0.958494
# 13   0.99695  0.010942        0.8538  1.019937
# 14   0.99910  0.003988        0.8552  1.115376
# 15   0.99850  0.004550        0.8542  1.151491
# 16   0.99635  0.010567        0.8442  1.037705
# 17   0.99670  0.010925        0.8544  1.235873
# 18   0.99780  0.006799        0.8540  1.209023
# 19   0.99915  0.003132        0.8540  1.244964

# %%
test(model, x_test, y_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8431 - loss: 1.2985
#        loss  accuracy
# 0  1.298496   0.84308

# %%
plot_results(model.name)

# %% [markdown]
# ## Odgovori
#
# V tem primeru gre očitno za nadprileganje. Začne se že po prvi epohi.
