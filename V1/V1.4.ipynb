# %% [markdown]
# # V 1.4

# %%
from common import *
# %load_ext autoreload
# %autoreload 2
sizes = [16, 4, 512]
# Out:
# 2026-01-05 18:38:20.024843: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-05 18:38:20.054216: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-05 18:38:20.750426: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
dim = 3000
x_train, y_train, x_test, y_test = load_dataset(dim)


models = []
for s in sizes:
    model = init_model(dim, s, 0.0, keras.regularizers.l2())
    model_name = f'model_{s}_l2_no-drop'
    train(model, x_train, y_train)
    models.append(model)
    model = init_model(dim, s, 0.25, None)
    model_name = f'model_{s}_no-reg_dropout'
    train(model, x_train, y_train)
    models.append(model)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767634707.773818   33554 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7167 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "model_3000_16_l2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │        48,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
for model in models:
    print(model.name)
    test(model, x_test, y_test)
# Out:
# model_3000_16_l2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 640us/step - accuracy: 0.8750 - loss: 0.4345
# model_3000_16_do0.25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 644us/step - accuracy: 0.8516 - loss: 1.2583
# model_3000_4_l2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 633us/step - accuracy: 0.8740 - loss: 0.4358
# model_3000_4_do0.25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 751us/step - accuracy: 0.8523 - loss: 0.6204
# model_3000_512_l2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.8728 - loss: 0.4327
# model_3000_512_do0.25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - accuracy: 0.8598 - loss: 0.9376

# %%
for s in sizes:
    plot_results(f'model_3000_{s}', f'model_3000_{s}_l2', f'model_3000_{s}_do0.25')

# %% [markdown]
# ## Odgovori
#
# Najboljše razultate po metriki točnosti je dosegla mreža z 512 skritimi nevroni, z ali brez dropoutom. Stabilnost učenja je najbolj izboljšala L2 regularizacija.
