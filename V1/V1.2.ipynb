# %% [markdown]
# # V 1.2

# %%
from common import *
# %load_ext autoreload
# %autoreload 2

model_name = 'model_4'
# Out:
# 2025-11-14 18:00:06.301537: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
dim = 3000
x_train, y_train, x_test, y_test = load_dataset(dim)

model = init_model(dim, 4)

train(model, x_train, y_train, model_name)
# Out:
# 2025-11-14 18:00:15.029939: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │        12,004 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,029 (46.99 KB)
#  Trainable params: 12,029 (46.99 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8138 - loss: 0.4939 - val_accuracy: 0.8778 - val_loss: 0.4026
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8967 - loss: 0.3480 - val_accuracy: 0.8804 - val_loss: 0.3526
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9101 - loss: 0.2897 - val_accuracy: 0.8760 - val_loss: 0.3380
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9186 - loss: 0.2557 - val_accuracy: 0.8764 - val_loss: 0.3375
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9225 - loss: 0.2344 - val_accuracy: 0.8720 - val_loss: 0.3591
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9293 - loss: 0.2183 - val_accuracy: 0.8650 - val_loss: 0.3571
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9329 - loss: 0.2053 - val_accuracy: 0.8694 - val_loss: 0.3636
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9365 - loss: 0.1945 - val_accuracy: 0.8728 - val_loss: 0.3801
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9406 - loss: 0.1831 - val_accuracy: 0.8704 - val_loss: 0.3865
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9444 - loss: 0.1719 - val_accuracy: 0.8676 - val_loss: 0.4156
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9481 - loss: 0.1625 - val_accuracy: 0.8670 - val_loss: 0.4266
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9543 - loss: 0.1493 - val_accuracy: 0.8662 - val_loss: 0.4503
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9582 - loss: 0.1393 - val_accuracy: 0.8660 - val_loss: 0.5272
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9636 - loss: 0.1302 - val_accuracy: 0.8640 - val_loss: 0.5368
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9682 - loss: 0.1211 - val_accuracy: 0.8610 - val_loss: 0.5672
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9696 - loss: 0.1165 - val_accuracy: 0.8626 - val_loss: 0.6118
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9718 - loss: 0.1102 - val_accuracy: 0.8610 - val_loss: 0.6373
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9722 - loss: 0.1085 - val_accuracy: 0.8590 - val_loss: 0.7408
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9732 - loss: 0.1058 - val_accuracy: 0.8554 - val_loss: 0.6626
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9748 - loss: 0.1009 - val_accuracy: 0.8606 - val_loss: 0.7571
#     accuracy      loss  val_accuracy  val_loss
# 0    0.81385  0.493880        0.8778  0.402615
# 1    0.89670  0.347997        0.8804  0.352584
# 2    0.91010  0.289714        0.8760  0.337960
# 3    0.91855  0.255689        0.8764  0.337476
# 4    0.92250  0.234412        0.8720  0.359120
# 5    0.92925  0.218317        0.8650  0.357077
# 6    0.93290  0.205268        0.8694  0.363611
# 7    0.93650  0.194527        0.8728  0.380144
# 8    0.94065  0.183139        0.8704  0.386528
# 9    0.94435  0.171854        0.8676  0.415592
# 10   0.94815  0.162492        0.8670  0.426645
# 11   0.95435  0.149286        0.8662  0.450253
# 12   0.95815  0.139343        0.8660  0.527216
# 13   0.96360  0.130205        0.8640  0.536778
# 14   0.96820  0.121113        0.8610  0.567192
# 15   0.96960  0.116533        0.8626  0.611848
# 16   0.97180  0.110176        0.8610  0.637260
# 17   0.97220  0.108507        0.8590  0.740822
# 18   0.97320  0.105804        0.8554  0.662569
# 19   0.97485  0.100938        0.8606  0.757121

# %%
test(model, x_test, y_test, model_name)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8476 - loss: 0.7781
#       loss  accuracy
# 0  0.77813   0.84756

# %%
plot_results('model_16', model_name)

# %% [markdown]
# ## Odgovori
#
# Preprileganje se začne takoj, izguba in natančnost sta optimistični
