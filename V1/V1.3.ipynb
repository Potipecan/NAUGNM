# %% [markdown]
# # V 1.3

# %%
from common import *
# %load_ext autoreload
# %autoreload 2
# Out:
# 2025-11-18 19:13:56.961822: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
dim = 3000
x_train, y_train, x_test, y_test = load_dataset(dim)

model = init_model(dim, 512)

train(model, x_train, y_train)
# Out:
# 2025-11-18 19:14:05.482803: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "model_3000_512"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │     1,536,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,799,681 (6.87 MB)
#  Trainable params: 1,799,681 (6.87 MB)
#  Non-trainable params: 0 (0.00 B)
# 2025-11-18 19:14:05.757180: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 240000000 exceeds 10% of free system memory.
#     accuracy      loss  val_accuracy  val_loss
# 0    0.85280  0.337366        0.8806  0.285251
# 1    0.91940  0.202288        0.8746  0.312754
# 2    0.97160  0.076116        0.8692  0.458369
# 3    0.99180  0.023767        0.8630  0.680889
# 4    0.99255  0.021433        0.8626  0.593927
# 5    0.99640  0.010436        0.8590  0.874933
# 6    0.99530  0.014124        0.8664  0.729981
# 7    0.99615  0.011086        0.8636  0.798523
# 8    0.99640  0.010866        0.8728  0.809082
# 9    0.99700  0.010789        0.8620  0.817223
# 10   0.99730  0.009122        0.8714  0.831438
# 11   0.99950  0.001881        0.8712  1.016643
# 12   0.99610  0.012859        0.8664  0.760946
# 13   0.99815  0.005948        0.8656  0.886765
# 14   0.99780  0.006998        0.8626  0.921140
# 15   0.99835  0.004920        0.8646  1.194601
# 16   0.99835  0.007616        0.8706  1.166615
# 17   0.99795  0.005395        0.8676  0.991694
# 18   0.99805  0.006277        0.8722  0.859874
# 19   0.99910  0.002587        0.8716  1.146899

# %%
test(model, x_test, y_test)
# Out:
#  11/782 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.8588 - loss: 0.9792
# 2025-11-18 19:17:30.710251: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 300000000 exceeds 10% of free system memory.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8634 - loss: 1.1535
#        loss  accuracy
# 0  1.153497    0.8634

# %%
plot_results('model_3000_16', 'model_3000_4', model.name)

# %% [markdown]
# ## Odgovori
#
# Preprileganje se začne takoj, izguba in natančnost sta optimistični
