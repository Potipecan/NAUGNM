# %% [markdown]
# # V 1.3

# %%
from common import *
# %load_ext autoreload
# %autoreload 2

model_name = 'model_512'
# Out:
# 2025-11-14 18:04:06.050730: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
dim = 3000
x_train, y_train, x_test, y_test = load_dataset(dim)

model = init_model(dim, 512)

train(model, x_train, y_train, model_name)
# Out:
# 2025-11-14 18:04:15.326217: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │     1,536,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,799,681 (6.87 MB)
#  Trainable params: 1,799,681 (6.87 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 25ms/step - accuracy: 0.8547 - loss: 0.3361 - val_accuracy: 0.8724 - val_loss: 0.3046
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.9207 - loss: 0.1999 - val_accuracy: 0.8776 - val_loss: 0.3154
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.9713 - loss: 0.0767 - val_accuracy: 0.8578 - val_loss: 0.4946
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - accuracy: 0.9928 - loss: 0.0219 - val_accuracy: 0.8550 - val_loss: 0.7249
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.9935 - loss: 0.0200 - val_accuracy: 0.8674 - val_loss: 0.6723
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9942 - loss: 0.0158 - val_accuracy: 0.8660 - val_loss: 0.8208
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 34ms/step - accuracy: 0.9957 - loss: 0.0124 - val_accuracy: 0.8646 - val_loss: 1.0053
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.9968 - loss: 0.0103 - val_accuracy: 0.8684 - val_loss: 0.8494
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.9978 - loss: 0.0072 - val_accuracy: 0.8704 - val_loss: 0.8998
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.9962 - loss: 0.0110 - val_accuracy: 0.8598 - val_loss: 0.9829
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9976 - loss: 0.0077 - val_accuracy: 0.8606 - val_loss: 0.9809
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.9972 - loss: 0.0087 - val_accuracy: 0.8656 - val_loss: 1.1046
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.9980 - loss: 0.0069 - val_accuracy: 0.8690 - val_loss: 0.9498
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.9986 - loss: 0.0048 - val_accuracy: 0.8664 - val_loss: 0.9096
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.9974 - loss: 0.0080 - val_accuracy: 0.8704 - val_loss: 0.8573
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.9991 - loss: 0.0043 - val_accuracy: 0.8710 - val_loss: 1.0198
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9985 - loss: 0.0047 - val_accuracy: 0.8656 - val_loss: 0.9115
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - accuracy: 0.9980 - loss: 0.0069 - val_accuracy: 0.8644 - val_loss: 1.1278
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 34ms/step - accuracy: 0.9980 - loss: 0.0066 - val_accuracy: 0.8584 - val_loss: 0.7868
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.9988 - loss: 0.0041 - val_accuracy: 0.8528 - val_loss: 1.4424
#     accuracy      loss  val_accuracy  val_loss
# 0    0.85465  0.336097        0.8724  0.304613
# 1    0.92070  0.199946        0.8776  0.315357
# 2    0.97130  0.076701        0.8578  0.494633
# 3    0.99280  0.021867        0.8550  0.724901
# 4    0.99350  0.020015        0.8674  0.672263
# 5    0.99425  0.015842        0.8660  0.820804
# 6    0.99570  0.012364        0.8646  1.005252
# 7    0.99680  0.010263        0.8684  0.849413
# 8    0.99780  0.007200        0.8704  0.899785
# 9    0.99615  0.010962        0.8598  0.982870
# 10   0.99760  0.007691        0.8606  0.980866
# 11   0.99720  0.008713        0.8656  1.104564
# 12   0.99795  0.006915        0.8690  0.949848
# 13   0.99860  0.004750        0.8664  0.909587
# 14   0.99740  0.008046        0.8704  0.857333
# 15   0.99905  0.004262        0.8710  1.019826
# 16   0.99855  0.004726        0.8656  0.911531
# 17   0.99805  0.006915        0.8644  1.127774
# 18   0.99805  0.006648        0.8584  0.786773
# 19   0.99880  0.004058        0.8528  1.442382

# %%
test(model, x_test, y_test, model_name)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8440 - loss: 1.5141
#        loss  accuracy
# 0  1.514112   0.84396

# %%
plot_results('model_16', 'model_4', model_name)

# %% [markdown]
# ## Odgovori
#
# Preprileganje se začne takoj, izguba in natančnost sta optimistični
