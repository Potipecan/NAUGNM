# %%
from models import *
from torch.utils.data import DataLoader
import os

# %reload_ext autoreload
# %autoreload 2

image_dataset = ImageDataset('../datasets/tpdne_faces')
image_dataloader = DataLoader(image_dataset, batch_size=8, shuffle=True, num_workers=0)

# %%
output_dir = 'outputs/V3.1'
snapshot_dir = os.path.join(output_dir, 'snapshots')
os.makedirs(snapshot_dir, exist_ok=True)

# %%
h = HyperParams(1e-3, 1e-3, 150)


gen = Gen()
dis = Discriminator()

train(gen, dis, h, image_dataloader, snapshot_dir)
# Out:
# Epoch 001: gen loss: 0.0538, dis loss: 98.4309
# Epoch 002: gen loss: 0.0000, dis loss: 100.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       4 gen = Gen()
#       5 dis = Discriminator()
# ----> 7 train(gen, dis, h, image_dataloader, snapshot_dir)
#
# File ~/Documents/faks/NAUGNM/V3/models.py:124, in train(gen, dis, h, real_data, image_output_folder)
#     121 gen_c_loss = 0
#     122 total = 0
# --> 124 for batch_idx, data in enumerate(real_data):
#     126     data = data.to(device=device) / 255.0
#     127     pred_real = dis(data)
#
# File ~/.conda/envs/basics/lib/python3.11/site-packages/torch/utils/data/dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# ...
